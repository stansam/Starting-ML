# %% [markdown]
# <a href="https://colab.research.google.com/github/stansam/Starting-ML/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

dataset = pd.read_excel('/content/retail-prices-for-dry-beans-2018.xlsx')
dataset
# Out:
#                                       Month/Town     Jan     Feb    Mar  \
# 0     Akala.....................................   80.98       -      -
# 1      Bomet....................................   71.16   66.66  78.85
# 2       Bondo...................................  100.28  100.22  93.41
# 3       Bumala..................................       -       -      -
# 4               Bungoma Town....................       -       -      -
# ..                                           ...     ...     ...    ...
# 96      Unguja..................................   98.75   98.13  95.38
# 97   Voi........................................       -       -      -
# 98        Wajir Town............................       -       -      -
# 99    Wote......................................       -       -      -
# 100   Total.....................................    88.1   88.74  88.84
#
#        Apr    May    Jun    Jul    Aug    Sep    Oct    Nov    Dec
# ...

# %%
dataset.head()
# Out:
#                                    Month/Town     Jan     Feb    Mar    Apr  \
# 0  Akala.....................................   80.98       -      -      -
# 1   Bomet....................................   71.16   66.66  78.85  70.94
# 2    Bondo...................................  100.28  100.22  93.41  95.03
# 3    Bumala..................................       -       -      -      -
# 4            Bungoma Town....................       -       -      -      -
#
#      May    Jun    Jul    Aug    Sep    Oct    Nov    Dec
# 0      -      -      -  71.34  74.91  72.21  81.19  81.45
# 1  70.77  77.78  73.08  71.15  69.93  64.62  69.23      -
# 2  99.28  70.74  90.91      -      -      -      -      -
# 3  69.05  73.02      -      -      -      -      -      -
# 4      -      -     73  88.21      -      -      -      -

# %%
dataset.tail()
# Out:
#                                       Month/Town    Jan    Feb    Mar    Apr  \
# 96      Unguja..................................  98.75  98.13  95.38    100
# 97   Voi........................................      -      -      -      -
# 98        Wajir Town............................      -      -      -      -
# 99    Wote......................................      -      -      -    110
# 100   Total.....................................   88.1  88.74  88.84  90.52
#
#        May    Jun    Jul    Aug    Sep    Oct    Nov    Dec
# 96   74.44  69.33  74.11  75.28  74.17  72.63  81.68  83.33
# 97       -      -  63.33      -      -      -      -      -
# 98       -      -      -    120      -      -      -      -
# 99       -   97.5     90     80    100      -  86.67     95
# 100   87.5  85.03  82.07  75.72  74.55  74.42  74.95   76.8

# %%
dataset.dropna()
# Out:
#                                       Month/Town     Jan     Feb    Mar  \
# 0     Akala.....................................   80.98       -      -
# 1      Bomet....................................   71.16   66.66  78.85
# 2       Bondo...................................  100.28  100.22  93.41
# 3       Bumala..................................       -       -      -
# 4               Bungoma Town....................       -       -      -
# ..                                           ...     ...     ...    ...
# 96      Unguja..................................   98.75   98.13  95.38
# 97   Voi........................................       -       -      -
# 98        Wajir Town............................       -       -      -
# 99    Wote......................................       -       -      -
# 100   Total.....................................    88.1   88.74  88.84
#
#        Apr    May    Jun    Jul    Aug    Sep    Oct    Nov    Dec
# ...

# %%
array = np.array(dataset)
